# %%
import numpy as np
m = 3
c = 4
sigma = 5
mu = 10
np.random.seed(1)
X = np.linspace(10,60,100)   #uniformly distributed set of numbers within given range
#print(X[:5])
noise = sigma * np.random.randn(100) + mu
#noise = np.ramdom.normal(10,50,100)
y = m* X + c + noise

print(X[:5], y[:5])
# Out:
# [10.         10.50505051 11.01010101 11.51515152 12.02020202] [52.12172682 42.45636945 44.38944427 43.18061143 54.38764421]

# %%
# ?np.random.randn   #help

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5,5))
plt.scatter(X, y)
plt.xlabel('Input Feature')   
plt.ylabel('Output(y)')
plt.title('Scatter Plot ')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5,5))
s = np.linspace(0, 2*3.14, 1000)
plt.scatter(s, np.sin(s))
#plt.plot((s, np.sin(s))
plt.xlabel('X')   
plt.ylabel('Output(y)')
plt.title('Sin function between 0 and $\pi$')
plt.grid(True)
plt.show()

# %%
add_dummy_feature(X)

# %%
def predict(X, w):
  y_hat = X @ w
  return y_hat

# %%
def model(w0, w1):  
  np.random.seed(1)
  X = np.linspace(1,100,100)   #uniformly distributed set of numbers within given range
  y = w1* X + w0

  plt.figure(figsize=(5,5))
  plt.scatter(X, y)
  plt.xlabel('Input Feature')   
  plt.ylabel('Output(y)')
  plt.title('Scatter Plot ')
  plt.grid(True)
  plt.show()

# %%
model(2,1)

# %%
a = np.arange(6).reshape(-1, 2)
print(a)

inv_a = np.linalg.pinv(a)
print(inv_a)

w1 = np.linalg.pinv(a) @ y
# Out:
# [[0 1]
#  [2 3]
#  [4 5]]
# [[-1.08333333 -0.33333333  0.41666667]
#  [ 0.83333333  0.33333333 -0.16666667]]

# %%
#X = np.linspace(1,100,100)   #uniformly distributed set of numbers within given range
#y = X + 2
x = np.column_stack((np.ones(X.shape[0]),X))

plt.scatter(X, y)
plt.plot(X, x@w,'r')
#plt.show()

# %%
w_new = w -
